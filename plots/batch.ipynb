# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### duration = 100
# ### throughput_per_second = 13000
# ### window_duration = 10

# %%
def plot_throughput(consumer,t):

    x=[]
    for i in range(len(consumer)):
        x.append(i)
    labels=x
    producer=[]
    sum=0
    for i in range(len(t)):
        sum+=t[i]
        if(i==0):
            continue
        if(i%10==9):
            producer.append(sum/10)
            sum=0
    producer.append(sum/10)
    # Plotting x-axis and y-axis
    sum=0
    for i in consumer:
        sum+=i
    print("Consumer avg throughput ",sum/len(consumer))

    sum=0
    for i in producer:
        sum+=i
    print("Producer avg throughput ",sum/len(producer))
    plt.plot(x, consumer)
    plt.plot(x,producer)
    # naming of x-axis and y-axis
    plt.xlabel("X-Axis")
    plt.ylabel("Y-Axis")
    
    # naming the title of the plot
    plt.title("Set X-Axis Values in Matplotlib")
    
    # setting x-axis values
    plt.xticks(x, labels)
    
    plt.show()

# %%
def plot_latency(y):
    x=[]
    for i in range(len(y)):
        x.append(i)
    labels=x
    sum=0
    for i in y:
        sum+=i
    print("Latency ",sum)
    # Plotting x-axis and y-axis
    plt.plot(x, y)
    
    # naming of x-axis and y-axis
    plt.xlabel("X-Axis")
    plt.ylabel("Y-Axis")
    
    # naming the title of the plot
    plt.title("Set X-Axis Values in Matplotlib")
    
    # setting x-axis values
    plt.xticks(x, labels)
    
    plt.show()

# %%
consumer = [1278.9194303484294, 1395.7295442897944, 1536.5776397221869, 1708.9757800534499, 1930.5762407724396, 2231.514745514711, 2643.1326473197764, 3236.8541641830034, 4183.680434526061, 5907.740990274632, 759.7046572174601]
t= [13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000]

# %%
plot_throughput(consumer,t)
# Out:
# Consumer avg throughput  2437.5823885656314
# Producer avg throughput  11936.363636363636

# %%
latency =  [100, 0.000101648311, 9.314125400000001e-05, 8.46036e-05, 7.6068954e-05, 6.733740799999999e-05, 5.8256393e-05, 4.9184062e-05, 4.0162452e-05, 3.1073119e-05, 2.2005026999999997e-05]
plot_latency(latency)
# Out:
# Latency  100.00062348058

# %% [markdown]
# ### Throughput = 15000

# %%
t= [15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000]
consumer= [1472.2692925800034, 1603.108782751165, 1754.8468020496657, 1938.5425659619477, 2189.692507174418, 2502.2021881457867, 2938.7509638368474, 3556.7899250084038, 4499.946450637237, 6129.528710344707, 764.9476117978584]
latency =  [100, 0.00010188353499999999, 9.356819799999999e-05, 8.5477547e-05, 7.7377718e-05, 6.8502769e-05, 5.9947194000000005e-05, 5.1042093e-05, 4.2172859000000005e-05, 3.3333730000000005e-05, 2.4471702e-05]

# %%
plot_throughput(consumer,t)
# Out:
# Consumer avg throughput  2668.238709117095
# Producer avg throughput  13772.727272727272

# %%
plot_latency(latency)
# Out:
# Latency  100.000637777345

# %% [markdown]
# ### Throughput =50000

# %%
t= [50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 12006]
consumer = [4732.94540156538, 5028.606131126014, 5391.2764144509665, 5811.664368385876, 6296.204301755665, 6870.239087480554, 7549.992767861928, 8274.871777965596, 9191.046714634616, 10390.112569388808, 277.6065056573598]
latency =  [100, 0.000105642461, 9.9431132e-05, 9.2742416e-05, 8.6033874e-05, 7.9412925e-05, 7.2777671e-05, 6.6225229e-05, 6.0423896999999994e-05, 5.4400768e-05, 4.8122674e-05]
# Matches =  [65249, 65544, 65764, 65635, 65506, 65648, 65519, 65882, 65809, 65534, 1554]

# %%
plot_throughput(consumer,t)
# Out:
# Consumer avg throughput  6346.778730933886
# Producer avg throughput  45563.69090909091

# %%
plot_latency(latency)
# Out:
# Latency  100.00076521304699

# %% [markdown]
# ### Throughput - 150000

# %%
t=  [91706, 91860, 90898, 92283, 93020, 92279, 90840, 92650, 92112, 92521, 91017, 91371, 92821, 92376, 91884, 92566, 92576, 92112, 90083, 91790, 92000, 91823, 91816, 89176, 92704, 91110, 91637, 91670, 92129, 91926, 92098, 90891, 91493, 91942, 90523, 92857, 92285, 92961, 92864, 91680, 91985, 91655, 91979, 92114, 91847, 92343, 91802, 90958, 91260, 91509, 78447]
consumer = [8374.704892515068, 9586.745695497477, 11207.603489103178, 13579.859100511285, 17106.60729776028, 2002.7563269989691]
latency =  [100, 0.000109874797, 9.5819377e-05, 8.172942600000001e-05, 6.771749199999999e-05, 5.3631441e-05]
# Matches =  [60244, 60326, 60053, 60001, 60242, 10259]

# %%
plot_throughput(consumer,t)
# Out:
# Consumer avg throughput  10309.71280039771
# Producer avg throughput  77837.48333333334

# %%
plot_latency(latency)
# Out:
# Latency  100.000408772533

# %% [markdown]
# ### Throughput = 25000

# %%
t= [25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000]
consumer=  [2419.647522396112, 2601.8210978446564, 2814.6646143032995, 3099.352778275947, 3453.5983573139, 3901.755117140131, 4483.081513862746, 5263.165096962764, 6382.365473138793, 8104.354784274557, 960.269317901114]
latency =  [100, 0.00010332083400000001, 9.6086545e-05, 8.8820529e-05, 8.0662002e-05, 7.2388267e-05, 6.4073729e-05, 5.5765214e-05, 4.7499935e-05, 3.917043e-05, 3.0847613e-05]
# Matches =  [32924, 32889, 32814, 32835, 32951, 32956, 32803, 32729, 32916, 32663, 3252]

# %%
plot_throughput(consumer,t)
# Out:
# Consumer avg throughput  3953.097788492183
# Producer avg throughput  22954.545454545456

# %%
plot_latency(latency)
# Out:
# Latency  100.00067863509801

# %% [markdown]
# ### Throughput = 75000

# %%
t=[75000, 75000, 75000, 75000, 75000, 75000, 75000, 67491, 75000, 75000, 75000, 75000, 55514, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 63555, 75000, 75000, 70969, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 66073]
consumer=  [6901.3549908192745, 7204.059125997221, 7868.367788198982, 8307.589866162623, 8801.943112267096, 9356.496475613621, 9797.271792381986, 11049.231160611535, 11935.440913647499, 8427.930273249394]
latency =  [100, 0.000107586264, 0.00010140311, 9.531837099999999e-05, 9.0278891e-05, 8.520845799999999e-05, 8.0158209e-05, 7.497230000000001e-05, 6.787802600000001e-05, 6.2838064e-05]
# Matches =  [87409, 85780, 98242, 98499, 98150, 98341, 76329, 98248, 98333, 67515]

# %%
plot_throughput(consumer,t)
# Out:
# Consumer avg throughput  8964.968549894924
# Producer avg throughput  72236.02

# %%
plot_latency(latency)
# Out:
# Latency  100.00076564169298

# %%
x=[13000,15000,25000,50000,75000,150000]
y1=[2437.5823885656314,2668.238709117095,3953.097788492183,6346.778730933886,8964.968549894924,10309.71280039771]
y2=[11936.363636363636,13772.727272727272,22954.545454545456,45563.69090909091,72236.02,77837.48333333334]
y3=[100.00062348058,100.000637777345,100.00067863509801,100.00076521304699,100.00076564169298,100.000408772533]
labels=x
plt.plot(x, y1)
plt.plot(x,y2)
plt.plot(x,y3)
# naming of x-axis and y-axis
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")

# naming the title of the plot
plt.title("Set X-Axis Values in Matplotlib")

# setting x-axis values
plt.xticks(x, labels)

plt.show()
