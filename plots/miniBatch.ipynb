# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### duration = 100
# ### throughput_per_second = 13000
# ### window_duration = 10

# %%
def plot_throughput(consumer,t):

    x=[]
    for i in range(len(consumer)):
        x.append(i)
    labels=x
    producer=[]
    sum=0
    for i in range(len(t)):
        sum+=t[i]
        if(i==0):
            continue
        if(i%10==9):
            producer.append(sum/10)
            sum=0
    producer.append(sum/10)
    # Plotting x-axis and y-axis
    sum=0
    for i in consumer:
        sum+=i
    print("Consumer avg throughput ",sum/len(consumer))

    sum=0
    for i in producer:
        sum+=i
    print("Producer avg throughput ",sum/len(producer))
    plt.plot(x, consumer)
    plt.plot(x,producer)
    # naming of x-axis and y-axis
    plt.xlabel("X-Axis")
    plt.ylabel("Y-Axis")
    
    # naming the title of the plot
    plt.title("Set X-Axis Values in Matplotlib")
    
    # setting x-axis values
    plt.xticks(x, labels)
    
    plt.show()

# %%
def plot_latency(y):
    x=[]
    for i in range(len(y)):
        x.append(i)
    labels=x
    sum=0
    for i in y:
        sum+=i
    print("Latency ",sum)
    # Plotting x-axis and y-axis
    plt.plot(x, y)
    
    # naming of x-axis and y-axis
    plt.xlabel("X-Axis")
    plt.ylabel("Y-Axis")
    
    # naming the title of the plot
    plt.title("Set X-Axis Values in Matplotlib")
    
    # setting x-axis values
    plt.xticks(x, labels)
    
    plt.show()

# %%
consumer = [11070.748298276958, 9742.490975080957, 8351.67946566094, 8432.324498678849, 7241.912239224821, 7378.830521204261, 6845.4559553519975, 6700.28785271809, 6792.714009549407, 2611.8688544483844]
t= [13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 6769, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 5867, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 7825, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 8150, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000, 13000]

# %%
plot_throughput(consumer,t)
# Out:
# Consumer avg throughput  7516.831267019466
# Producer avg throughput  12116.11

# %%
latency=[1.1742657e-05, 10, 1.334361e-05, 10, 1.4819654e-05, 10, 1.5416864e-05, 10, 1.6966099e-05, 10, 1.7617968000000002e-05, 10, 1.8234724e-05, 10, 1.8678302e-05, 10, 1.9138153e-05, 10]
plot_latency(latency)
# Out:
# Latency  90.00014595803098

# %% [markdown]
# ### Throughput = 15000

# %%
t=[15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 12328, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 9711, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 11044, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 5869, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 14137, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 3260, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 15000, 5867, 15000, 15000, 15000, 15000, 15000]
consumer = [12632.32784495182, 10745.5372921812, 9967.33895516478, 9524.797120986523, 8730.499401497615, 8819.086699385974, 8489.907028726111, 7522.8012809547, 7421.735690489276, 2902.2150378146]
latency =[1.1874296e-05, 10, 1.3710622e-05, 10, 1.4518519e-05, 10, 1.5333030000000003e-05, 10, 1.6135274e-05, 10, 1.6910708e-05, 10, 1.7668037999999998e-05, 10, 1.8378792e-05, 10, 1.8980331e-05, 10]

# %%
plot_throughput(consumer,t)
# Out:
# Consumer avg throughput  8675.62463521526
# Producer avg throughput  13372.159999999998

# %%
plot_latency(latency)
# Out:
# Latency  90.00014350961001

# %% [markdown]
# ### Throughput =50000

# %%
t= [50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 16299, 1304, 2282, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 5173, 326, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 5866, 5543, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 1956, 5156, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 28357, 3585, 30723, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 1181, 1630, 18836, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 50000, 25064]
consumer=  [31789.275252208165, 18572.36163857954, 18854.591220527425, 17009.164654951794, 15773.080148054141, 16444.510035885876, 13143.046029863972, 10591.359125294011, 4484.380401302659]
latency =  [1.5728575e-05, 10, 1.9915884e-05, 10, 2.1506644999999998e-05, 10, 2.418749e-05, 10, 2.5810558e-05, 10, 2.9089161e-05, 10, 3.3044699e-05, 10, 3.5089642e-05, 10]
# Matches =  [65705, 28925, 39826, 39826, 46802, 62514, 43992, 29032, 22946]

# %%
plot_throughput(consumer,t)
# Out:
# Consumer avg throughput  16295.752056296398
# Producer avg throughput  39480.9

# %%
plot_latency(latency)
# Out:
# Latency  80.00020437265401

# %% [markdown]
# ### Throughput = 150000

# %%
t=  [92160, 92855, 93395, 93714, 92790, 83604, 2609, 4563, 69276, 72038, 90684, 94615, 93373, 93207, 93490, 883, 7740, 87997, 92049, 106537, 137286, 93735, 92256, 93165, 93525, 4074, 679, 88068, 86618, 91594, 111375, 93460, 92849, 93979, 91743, 5216, 1659, 59673, 87084, 93411, 91051, 91666, 93232, 93731, 93878, 18257, 2608]
consumer=  [32193.17276287341, 36341.00311911332, 33103.83848225301, 31713.308139084435, 18891.127109917623]
latency =  [2.1564447999999998e-05, 10, 2.0732174e-05, 10, 2.0954428e-05, 10, 2.2006345e-05, 10]
# Matches =  [60843, 61023, 66920, 63473, 61155]

# %%
plot_throughput(consumer,t)
# Out:
# Consumer avg throughput  30448.489922648354
# Producer avg throughput  69069.01999999999

# %%
plot_latency(latency)
# Out:
# Latency  40.000085257395

# %% [markdown]
# ### Throughput = 25000

# %%
t=  [25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 23471, 10699, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 11083, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 3860, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 14343, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 13303, 8667, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 4564, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 10674, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000, 25000]
consumer = [18941.71286424156, 14464.984292486095, 13833.574857246387, 12134.46295643152, 11342.262777230118, 10129.497574273513, 10092.584972140801, 9662.052817860953, 9552.57679039457, 685.1996733516118]
latency =  [1.3198384e-05, 10, 1.6188749e-05, 10, 1.7065943e-05, 10, 1.8860332e-05, 10, 2.1101873999999998e-05, 10, 2.1913229e-05, 10, 2.2745808e-05, 10, 2.4391711000000002e-05, 10, 2.6170949e-05, 10]
# Matches =  [32650, 24088, 27703, 26723, 24845, 22656, 26822, 29989, 32713, 3272]

# %%
plot_throughput(consumer,t)
# Out:
# Consumer avg throughput  11083.890957565713
# Producer avg throughput  21506.64

# %%
plot_latency(latency)
# Out:
# Latency  90.000181636979

# %% [markdown]
# ### Throughput = 75000

# %%
t=  [75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 27709, 1250, 1917, 3910, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 67344, 5866, 63464, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 72032, 2282, 1631, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 6506, 10756, 9453, 75000, 75000, 75000, 75000, 75000, 72795, 75000, 54224, 6907, 5865, 1630, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 75000, 3587, 3586, 59180, 75000, 75000, 75000]
consumer=  [43249.759228590374, 21320.08002297428, 26550.023341023792, 22206.61088860588, 19084.642811407968, 18468.37528987619, 19159.97675872704, 7570.4934565724225]
latency =  [1.7341137e-05, 10, 2.273847e-05, 10, 2.4921786e-05, 10, 2.7061536e-05, 10, 2.8908846e-05, 10, 3.1935186e-05, 10, 3.5314760999999996e-05, 10]
# Matches =  [98544, 24231, 47418, 49271, 71054, 75791, 79158, 38284]

# %%
plot_throughput(consumer,t)
# Out:
# Consumer avg throughput  22201.245224722243
# Producer avg throughput  58523.674999999996

# %%
plot_latency(latency)
# Out:
# Latency  70.000188221722

# %%
x=[13000,15000,25000,50000,75000,150000]
y1=[7516.831267019466,8675.62463521526,11083.890957565713,16295.752056296398,22201.245224722243,30448.489922648354]
y2=[12116.11,13372.159999999998,21506.64,39480.9,58523.674999999996,69069.01999999999]
y3=[100.00014595803098,100.00014350961001,100.000181636979,100.00020437265401,100.000188221722,100.000085257395]
labels=x
plt.plot(x, y1)
plt.plot(x,y2)
plt.plot(x,y3)
# naming of x-axis and y-axis
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")

# naming the title of the plot
plt.title("Set X-Axis Values in Matplotlib")

# setting x-axis values
plt.xticks(x, labels)

plt.show()
